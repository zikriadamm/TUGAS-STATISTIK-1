# %%
# import
from sklearn.linear_model import LinearRegression
import pandas as pd
import matplotlib.pyplot as plt

# %%
model = LinearRegression()

df = pd.read_csv("../dataset/data_nilai.csv")

x = df[["jam_belajar"]]
y = df["nilai_ujian"]


# train
model.fit(x, y);
# Out:
# LinearRegression()

# %%
new_data = pd.DataFrame([[15]], columns=["jam_belajar"])

# prediction
prediction = model.predict(new_data)

print(f"prediksi nilai ujian dengan 15 jam belajar {prediction}")
# Out:
# prediksi nilai ujian dengan 15 jam belajar [89.18496241]

# %%
# visualisasi
plt.scatter(x, y)

plt.plot(
    x,
    model.predict(x),
)

plt.xlabel("tahun bekerja")
plt.ylabel("gaji")
plt.title("Linear Regression")

plt.savefig("linear_regression.png")
plt.show()
